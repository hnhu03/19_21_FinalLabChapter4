# %%
import nltk
import re
import os
from nltk.probability import FreqDist
from nltk.corpus import stopwords
st=''
src='D:/KhAI PHA WEB/bt2.11/Data_Preprocessing'
path=os.listdir(src)
for i in path:
    label=i.split("'")[0]
    f=open('D:/KhAI PHA WEB/bt2.11/Data_Preprocessing/'+str(label), "r", encoding="utf-8")
    text=f.read()
    st+=text 
text_pre=[]
text_pre=st.split('\n')
print("Number of words: ",len(text_pre))

# Compute the frequency of all words
frequency_dist = FreqDist(word.lower() for word in text_pre)

## show only th top 50 results
print(frequency_dist.most_common(50))


## Consider words with length greater than 3 and plot
large_words = dict([(k,v) for k,v in frequency_dist.items() if len(k)>3])
frequency_dist = nltk.FreqDist(large_words)
frequency_dist.plot(50,cumulative=False)


from wordcloud import WordCloud
wcloud = WordCloud().generate_from_frequencies(frequency_dist)
#plotting the wordcloud
import matplotlib.pyplot as plt
plt.imshow(wcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# Number of words:  7463
# [('không', 303), ('quán', 154), ('ngon', 92), ('đi', 88), ('món', 79), ('giá', 68), ('nhân_viên', 67), ('phục_vụ', 66), ('i', 58), ('bánh', 53), ('gọi', 52), ('hơi', 49), ('xe', 48), ('lắm', 47), ('uống', 47), ('mua', 47), ('người', 46), ('bàn', 46), ('tiền', 45), ('n', 41), ('được', 38), ('đông', 36), ('xong', 36), ('kêu', 35), ('đợi', 35), ('thịt', 35), ('cua', 34), ('trà', 34), ('vị', 34), ('thử', 33), ('chả', 33), ('order', 30), ('t', 29), ('đồ_ăn', 29), ('đồ', 28), ('nướng', 27), ('bảo', 27), ('chỗ', 26), ('không_gian', 26), ('mấy', 25), ('nh', 24), ('bình_thường', 24), ('lẩu', 24), ('cơm', 24), ('sữa', 23), ('đem', 22), ('y', 21), ('chị', 21), ('chất_lượng', 20), ('trứng', 20)]
