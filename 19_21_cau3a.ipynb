# %%
from sklearn.feature_extraction.text import CountVectorizer 
import nltk
import re
import os
from nltk.probability import FreqDist
from nltk.corpus import stopwords
import emoji

# Khởi tạo đối tượng CountVectorizer
# Tham số ngram_range=(1,2) cho biết chúng ta muốn sử dụng N-grams từ 1 đến 2.
vectorizer = CountVectorizer(ngram_range=(1,1))
v=[]
text2=''
f = open("D:/vnm/vnm/vietnamese-stopwords.txt", "r", encoding="utf-8")
#Get Stop words Dictionaries
List_StopWords=f.read().split("\n")
#Read file text
src='D:/KhAI PHA WEB/19/Data1-20231102T012633Z-001/Data1'
path=os.listdir(src)
for i in path:
    label=i.split("'")[0]
    f=open('D:/KhAI PHA WEB/19/Data1-20231102T012633Z-001/Data1/'+str(label), "r", encoding="utf-8")
    text=f.read()
    text_pre=text.replace("\n","")  # Remove the newline command
    text_pre=text.lower() # Convert text to lowercase
    text_pre = re.sub("\d+", " ", text_pre) # Remove number
    text_pre = re.sub(r"[!@#$[]()]'", "", text_pre) # Remove character: !@#$[]()
    text_pre=emoji.demojize(text_pre)
    stop = stopwords.words('english')   # Remove StopWords
    text_pre = " ".join(text_pre for text_pre in text_pre.split() if text_pre not in List_StopWords)
    text2=text2 +text_pre 
v=text2.split(" . ")
Data=[]
for i in v:
    text_i=re.sub(r'[^\w\s]','',i) # Remove punctuation
    Data.append(text_i)
Data=list(filter(None,Data))

vect = CountVectorizer()
X = vect.fit_transform(Data)
dictionary=list(vect.get_feature_names_out())
print("Words in dictionary: ", dictionary)
print("Vector Bag-of-Word: \n", X.toarray())
# Out:
# Words in dictionary:  ['add', 'ai_ngờ', 'ak', 'all', 'alot', 'also', 'always', 'ambiance', 'an', 'an_duyên', 'and', 'anger_symbol', 'anw', 'any', 'around', 'as', 'at', 'away', 'ba_nữ', 'back', 'banh', 'bao', 'bao_giờ', 'bao_gồm', 'bao_nhiêu', 'bar', 'bay', 'bbq', 'be', 'beaming_face_with_smiling_eyes', 'beerclub', 'before', 'ben', 'best', 'bh', 'bi', 'bia', 'big', 'bigc', 'bik', 'bill', 'bin', 'binh', 'biê', 'biệt', 'bjo', 'bla', 'blend', 'bn', 'bo', 'bong_bóng', 'bth', 'bthg', 'bu', 'bubbly', 'buffet', 'building', 'bung', 'buoi', 'but', 'buôn_bán', 'buông', 'buồn', 'buổi_trưa', 'bve', 'bye', 'bà_con', 'bài_trí', 'bàn', 'bàn_cãi', 'bàn_ghế', 'bày', 'bác_nào_đến_đây_ăn_thử_thì_tốt_nhất_là_tự_mang_giấy_ăn_đi', 'bán_buôn', 'báng', 'bánh', 'bánh_bao', 'bánh_bèo', 'bánh_canh', 'bánh_cuốn', 'bánh_mì', 'bánh_phồng_tôm', 'bánh_quy', 'bánh_trái', 'bánh_tráng', 'báo', 'báo_giá', 'bát', 'bây_giờ', 'bãi', 'bé', 'bé_bé', 'bé_tí', 'bé_tẹo', 'béo', 'bê', 'bên_cạnh', 'bên_nguyên', 'bì', 'bình', 'bình_dân', 'bình_dương', 'bình_luận', 'bình_phong', 'bình_quân', 'bình_thường', 'bí', 'bò', 'bòn', 'bòn_bon', 'bóc', 'bóng', 'bóng_dáng', 'bóng_ma', 'bô', 'bù_đắp', 'bún', 'bún_bò', 'bún_chả', 'bă', 'bơ', 'bơ_vơ', 'bơi', 'bư', 'bưng', 'bạn_bè', 'bản_thân', 'bảng', 'bảng_hiệu', 'bảo', 'bảo_trì', 'bảo_vệ', 'bấm', 'bất_ngờ', 'bất_tiện', 'bầy', 'bẩn', 'bận', 'bắc', 'bắp', 'bắt', 'bắt_mắt', 'bắt_đầu', 'bằm', 'bếp', 'bể', 'bịch', 'bọc', 'bọn', 'bỏ_dở', 'bỏ_qua', 'bố_trí', 'bốc', 'bổ', 'bột', 'bột_ngọt', 'bột_n